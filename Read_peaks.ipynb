# %%
import pandas as pd
import numpy as np

df = pd.read_csv("D:\\Data Quality Check\\Excel\\peaks.csv")

df
# Out:
#     peakid               pkname                       pkname2  \
# 0     ACHN               Aichyn                Aychin, Ashvin
# 1     AMAD           Ama Dablam                  Amai Dablang
# 2     AMOT             Amotsang                       Amatson
# 3     AMPG        Amphu Gyabjen                 Amphu Gyabien
# 4     AMPH              Amphu I                           NaN
# ..     ...                  ...                           ...
# 475   YAUP                Yaupa                           NaN
# 476   YLNG          Yalung Peak                           NaN
# 477   YNGS  Yangra Kangri South  Yangra South, Ganesh I South
# 478   YOKO            Yokopahar                    Nampa VIII
# 479   YUBR                Yubra                           NaN
#
#                                               location  heightm  heightf  \
# 0                    Chandi Himal (SW of Changwathang)     6055    19865
# ...
